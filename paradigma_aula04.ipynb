# %% [markdown]
# Guilherme Yoshikawa da Silva
#
# RA: 818133945
#
# Curso: Ciência da Computação
#
# Aula 04 - Exercício Prático 4

# %% [markdown]
# ## 1 Menor de dois pares: Escreva uma função que retorne o menor de dois números dados se ambos os números forem pares, mas retorna o maior se um dos dois for ímpar. Exemplo:
#
# menor_de_dois_pares(2,4) --&gt; 2
#
# menor_de_dois_pares (2,5) --&gt; 5

# %%
num1 = int(input("Insira um número: "))
num2 = int(input("Insira outro número: "))

def menor_de_dois_pares(num1,num2):
    if (num1 % 2) == 0 and (num2 % 2) == 0:
        if num1 < num2:
            print("Menor: ",num1)
        else:
            print("Menor:  ",num2)
    if (num1 % 2) == 1:
        print("Impar: ",num1)
    if (num2 % 2) == 1:
        print("Impar: ",num2)
        
menor_de_dois_pares(num1,num2)
# Out:
# Insira um número:  2
# Insira outro número:  4
# Menor:  2

# %% [markdown]
# ## 2 Mesma letra: Escreva uma função que receba uma string com duas palavras e retorne True se ambas palavras começarem com a mesma letra. Exemplo:
#
# mesma_letra(&#39;Cão covarde&#39;) -&gt; True
#
# mesma_letra(&#39;Vira Lata&#39;) -&gt; False

# %%
palavra1 = input('Insira uma palavra: ')
palavra2 = input('Insira outra palavra: ')

l1 = list(palavra1)
l2 = list(palavra2)

def mesma_letra(l1,l2):
    if l1[0]== l2[0]:
        return True
    else:
        return False
    
mesma_letra(palavra1,palavra2)
# Out:
# Insira uma palavra:  cao
# Insira outra palavra:  covarde
# True

# %% [markdown]
# ## 3 Mestre Yoda: Dada uma sentença, a função deve retornar a sentença com as palavras na ordem reversa. Exemplo:
#
# mestre_yoda(&#39;Eu estou em casa&#39;) --&gt; &#39;casa em estou Eu&#39;
#
# mestre_yoda(&#39;Estamos prontos&#39;) --&gt; &#39;prontos Estamos&#39;

# %%
frase = input('Senteça: ')

def mestre_yoda(frase):
    p = frase.split()
    p.reverse()
    yoda = ""
    for i in range(0, len(p) - 1):
        p[i] = p[i] + " "
    for palavra in p:
        yoda += palavra
    return yoda

print(f"Invertida: '{mestre_yoda(frase)}'")
# Out:
# Senteça:  mestre yoda
# Invertida: 'yoda mestre'

# %% [markdown]
# ## 4 Tem 33: Faça uma função que retorne True se, dada uma lista de inteiros, houver em alguma posição da lista um 3 do lado de outro 3. Exemplo:
#
# tem_33([1,3,3]) --&gt; True
#
# tem_33([1,3,1,3]) --&gt; False
#
# tem_33([3,1,3]) --&gt; False

# %%
def tem_33(num):
    t = False
    for i in num:
        if i == 3:
            if t is True:
                return True
            else:
                t = True
        else:
            t = False
    else:
        return False
    
lista = list(input("Lista: ").split(" "))
tem_33(lista)
# Out:
# Lista:  1,2,3
# False

# %% [markdown]
# ## 5 Blackjack: Faça uma função que receba 3 inteiros entre 1 e 11. Se a soma deles for menor que 21, retorne o valor da soma. Se for mair do que 21 e houver um 11, subtraia 10 da soma antes de apresentar o resultado. Se o valor da soma passar de 21, retorne ‘ESTOUROU’. Exemplo:
#
# blackjack(5,6,7) --&gt; 18
#
# blackjack(9,9,9) --&gt; &#39;ESTOUROU&#39;
#
# blackjack(9,9,11) --&gt; 19

# %%
n1 = int(input('Número 1: '))
n2 = int(input('Número 2: '))
n3 = int(input('Número 3: '))

def blackjack(n1, n2, n3):
    if (1 <= n1 <= 11) and (1 <= n2 <= 11) and (1 <= n3 <= 11):
        if n1 + n2 + n3 <= 21:
            return n1 + n2 + n3
        else:
            if n1 == 11 or n2 == 11 or n3 == 11:
                return n1 + n2 + n3 - 10
            else:
                return "Estourou"
    else:
        return "Os números não estão entre 1 e 11."
    
print(f'Blackjack = {blackjack(n1, n2, n3)}')
# Out:
# Número 1:  1
# Número 2:  3
# Número 3:  5
# Blackjack = 9

# %% [markdown]
# ## 6 Espião: Escreva uma função que receba uma lista de inteiros e retorne True se contém um 007 em ordem, mesmo que não contínuo. Exemplo:
#
# espiao([1,2,4,0,0,7,5]) --&gt; True
#
# espiao([1,0,2,4,0,5,7]) --&gt; True
#
# espiao([1,7,2,4,0,5,0]) --&gt; False

# %%
list = []
for c in range (0, 7):
    list.append(int(input('Insira um número: ')))
    
def espiao(l):
    for x in range(0, len(list)):
        if list[x] == 0 and x + 1 < len(list):
            y = x + 1
            for y in range(y, len(list)):
                if list[y] == 0 and y + 1 < len(list):
                    z = y + 1
                    for z in range(z, len(list)):
                        if list[z] == 7:
                            return True
    return False

print(f'Espião = {espiao(list)}')
# Out:
# Insira um número:  0
# Insira um número:  0
# Insira um número:  7
# Insira um número:  1
# Insira um número:  2
# Insira um número:  3
# Insira um número:  4
# Espião = True
